# %%
# !pip install pandas-datareader
# !pip install "yfinance[nospam]"
# Out:
# Requirement already satisfied: yfinance[nospam] in c:\users\mhafi\anaconda3\lib\site-packages (0.2.43)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2.4.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2024.2)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (4.9.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2.5.2)
# Requirement already satisfied: requests>=2.31 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2.32.3)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.21.0)
# Requirement already satisfied: html5lib>=1.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.1)
# Collecting requests-ratelimiter>=0.3.1
#   Downloading requests_ratelimiter-0.7.0-py3-none-any.whl (9.3 kB)
# Collecting requests-cache>=1.0
#   Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#      -------------------------------------- 61.4/61.4 kB 105.8 kB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\mhafi\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance[nospam]) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mhafi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance[nospam]) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\mhafi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance[nospam]) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mhafi\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance[nospam]) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (3.3)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: attrs>=21.2 in c:\users\mhafi\anaconda3\lib\site-packages (from requests-cache>=1.0->yfinance[nospam]) (21.4.0)
# Collecting cattrs>=22.2
#   Downloading cattrs-24.1.1-py3-none-any.whl (66 kB)
#      -------------------------------------- 66.4/66.4 kB 597.6 kB/s eta 0:00:00
# Collecting pyrate-limiter<3.0
#   Downloading pyrate_limiter-2.10.0-py3-none-any.whl (16 kB)
# Collecting exceptiongroup>=1.1.1
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in c:\users\mhafi\anaconda3\lib\site-packages (from cattrs>=22.2->requests-cache>=1.0->yfinance[nospam]) (4.12.2)
# Collecting attrs>=21.2
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      --------------------------------------- 63.0/63.0 kB 57.2 kB/s eta 0:00:00
# Installing collected packages: url-normalize, pyrate-limiter, exceptiongroup, attrs, requests-ratelimiter, cattrs, requests-cache
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
# Successfully installed attrs-24.2.0 cattrs-24.1.1 exceptiongroup-1.2.2 pyrate-limiter-2.10.0 requests-cache-1.2.1 requests-ratelimiter-0.7.0 url-normalize-1.4.3
# Requirement already satisfied: yfinance[nospam] in c:\users\mhafi\anaconda3\lib\site-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (4.11.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (3.17.6)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (4.9.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2.5.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.21.0)
# Requirement already satisfied: html5lib>=1.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2024.2)
# Requirement already satisfied: requests>=2.31 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2.32.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (2.4.4)
# Requirement already satisfied: requests-ratelimiter>=0.3.1 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (0.7.0)
# Requirement already satisfied: requests-cache>=1.0 in c:\users\mhafi\anaconda3\lib\site-packages (from yfinance[nospam]) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mhafi\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance[nospam]) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mhafi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance[nospam]) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\mhafi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance[nospam]) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mhafi\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance[nospam]) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (2022.9.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mhafi\anaconda3\lib\site-packages (from requests>=2.31->yfinance[nospam]) (1.26.11)
# Requirement already satisfied: attrs>=21.2 in c:\users\mhafi\anaconda3\lib\site-packages (from requests-cache>=1.0->yfinance[nospam]) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\mhafi\anaconda3\lib\site-packages (from requests-cache>=1.0->yfinance[nospam]) (24.1.1)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\mhafi\anaconda3\lib\site-packages (from requests-cache>=1.0->yfinance[nospam]) (1.4.3)
# Requirement already satisfied: pyrate-limiter<3.0 in c:\users\mhafi\anaconda3\lib\site-packages (from requests-ratelimiter>=0.3.1->yfinance[nospam]) (2.10.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in c:\users\mhafi\anaconda3\lib\site-packages (from cattrs>=22.2->requests-cache>=1.0->yfinance[nospam]) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in c:\users\mhafi\anaconda3\lib\site-packages (from cattrs>=22.2->requests-cache>=1.0->yfinance[nospam]) (4.12.2)

# %%
import requests
import bs4 as bs
import pickle
import os
import datetime as dt
import pandas as pd
import pandas_datareader as web
from lxml import html

# %%
def save_sp500_tickers():
    # Mengambil halaman dan membuat soup
    resp = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, "lxml")
    
    # Mencari tabel yang berisi data ticker
    table = soup.find('table', {'id': 'constituents'})
    
    tickers = []
    # Mengiterasi setiap baris tabel kecuali header
    for row in table.findAll('tr')[1:]:
        # Mendapatkan data dari tiga kolom yang diinginkan
        ticker = row.find_all('td')[0].text.strip()
        company_name = row.find_all('td')[1].text.strip()
        sector = row.find_all('td')[3].text.strip()
        
        # Menyimpan data ke list sebagai tuple
        tickers.append({'ticker' : ticker, 'company name' : company_name, 'sektor' : sector})

    # Menyimpan data ticker ke file pickle
    with open("sp500tickers.pickle", "wb") as f:
        pickle.dump(tickers, f)

    # Mencetak daftar ticker untuk verifikasi
    print(tickers)

    return tickers

# Memanggil fungsi untuk menjalankan dan menyimpan ticker
save_sp500_tickers()
# Out:
# [{'ticker': 'MMM', 'company name': '3M', 'sektor': 'Industrial Conglomerates'}, {'ticker': 'AOS', 'company name': 'A. O. Smith', 'sektor': 'Building Products'}, {'ticker': 'ABT', 'company name': 'Abbott Laboratories', 'sektor': 'Health Care Equipment'}, {'ticker': 'ABBV', 'company name': 'AbbVie', 'sektor': 'Biotechnology'}, {'ticker': 'ACN', 'company name': 'Accenture', 'sektor': 'IT Consulting & Other Services'}, {'ticker': 'ADBE', 'company name': 'Adobe Inc.', 'sektor': 'Application Software'}, {'ticker': 'AMD', 'company name': 'Advanced Micro Devices', 'sektor': 'Semiconductors'}, {'ticker': 'AES', 'company name': 'AES Corporation', 'sektor': 'Independent Power Producers & Energy Traders'}, {'ticker': 'AFL', 'company name': 'Aflac', 'sektor': 'Life & Health Insurance'}, {'ticker': 'A', 'company name': 'Agilent Technologies', 'sektor': 'Life Sciences Tools & Services'}, {'ticker': 'APD', 'company name': 'Air Products', 'sektor': 'Industrial Gases'}, {'ticker': 'ABNB', 'company name': 'Airbnb', 'sektor': 'Hotels, Resorts & Cruise Lines'}, {'ticker': 'AKAM', 'company name': 'Akamai Technologies', 'sektor': 'Internet Services & Infrastructure'}, {'ticker': 'ALB', 'company name': 'Albemarle Corporation', 'sektor': 'Specialty Chemicals'}, {'ticker': 'ARE', 'company name': 'Alexandria Real Estate Equities', 'sektor': 'Office REITs'}, {'ticker': 'ALGN', 'company name': 'Align Technology', 'sektor': 'Health Care Supplies'}, {'ticker': 'ALLE', 'company name': 'Allegion', 'sektor': 'Building Products'}, {'ticker': 'LNT', 'company name': 'Alliant Energy', 'sektor': 'Electric Utilities'}, {'ticker': 'ALL', 'company name': 'Allstate', 'sektor': 'Property & Casualty Insurance'}, {'ticker': 'GOOGL', 'company name': 'Alphabet Inc. (Class A)', 'sektor': 'Interactive Media & Services'}, {'ticker': 'GOOG', 'company name': 'Alphabet Inc. (Class C)', 'sektor': 'Interactive Media & Services'}, {'ticker': 'MO', 'company name': 'Altria', 'sektor': 'Tobacco'}, {'ticker': 'AMZN', 'company name': 'Amazon', 'sektor': 'Broadline Retail'}, {'ticker': 'AMCR', 'company name': 'Amcor', 'sektor': 'Paper & Plastic Packaging Products & Materials'}, {'ticker': 'AEE', 'company name': 'Ameren', 'sektor': 'Multi-Utilities'}, {'ticker': 'AAL', 'company name': 'American Airlines Group', 'sektor': 'Passenger Airlines'}, {'ticker': 'AEP', 'company name': 'American Electric Power', 'sektor': 'Electric Utilities'}, {'ticker': 'AXP', 'company name': 'American Express', 'sektor': 'Consumer Finance'}, {'ticker': 'AIG', 'company name': 'American International Group', 'sektor': 'Multi-line Insurance'}, {'ticker': 'AMT', 'company name': 'American Tower', 'sektor': 'Telecom Tower REITs'}, {'ticker': 'AWK', 'company name': 'American Water Works', 'sektor': 'Water Utilities'}, {'ticker': 'AMP', 'company name': 'Ameriprise Financial', 'sektor': 'Asset Management & Custody Banks'}, {'ticker': 'AME', 'company name': 'Ametek', 'sektor': 'Electrical Components & Equipment'}, {'ticker': 'AMGN', 'company name': 'Amgen', 'sektor': 'Biotechnology'}, {'ticker': 'APH', 'company name': 'Amphenol', 'sektor': 'Electronic Components'}, {'ticker': 'ADI', 'company name': 'Analog Devices', 'sektor': 'Semiconductors'}, {'ticker': 'ANSS', 'company name': 'Ansys', 'sektor': 'Application Software'}, {'ticker': 'AON', 'company name': 'Aon', 'sektor': 'Insurance Brokers'}, {'ticker': 'APA', 'company name': 'APA Corporation', 'sektor': 'Oil & Gas Exploration & Production'}, {'ticker': 'AAPL', 'company name': 'Apple Inc.', 'sektor': 'Technology Hardware, Storage & Peripherals'}, {'ticker': 'AMAT', 'company name': 'Applied Materials', 'sektor': 'Semiconductor Materials & Equipment'}, {'ticker': 'APTV', 'company name': 'Aptiv', 'sektor': 'Automotive Parts & Equipment'}, {'ticker': 'ACGL', 'company name': 'Arch Capital Group', 'sektor': 'Property & Casualty Insurance'}, {'ticker': 'ADM', 'company name': 'Archer Daniels Midland', 'sektor': 'Agricultural Products & Services'}, {'ticker': 'ANET', 'company nam ...
# [{'ticker': 'MMM', 'company name': '3M', 'sektor': 'Industrial Conglomerates'},
#  {'ticker': 'AOS',
#   'company name': 'A. O. Smith',
#   'sektor': 'Building Products'},
#  {'ticker': 'ABT',
#   'company name': 'Abbott Laboratories',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'ABBV', 'company name': 'AbbVie', 'sektor': 'Biotechnology'},
#  {'ticker': 'ACN',
#   'company name': 'Accenture',
#   'sektor': 'IT Consulting & Other Services'},
#  {'ticker': 'ADBE',
#   'company name': 'Adobe Inc.',
#   'sektor': 'Application Software'},
#  {'ticker': 'AMD',
#   'company name': 'Advanced Micro Devices',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'AES',
#   'company name': 'AES Corporation',
#   'sektor': 'Independent Power Producers & Energy Traders'},
#  {'ticker': 'AFL',
#   'company name': 'Aflac',
#   'sektor': 'Life & Health Insurance'},
#  {'ticker': 'A',
#   'company name': 'Agilent Technologies',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'APD',
#   'company name': 'Air Products',
#   'sektor': 'Industrial Gases'},
#  {'ticker': 'ABNB',
#   'company name': 'Airbnb',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'AKAM',
#   'company name': 'Akamai Technologies',
#   'sektor': 'Internet Services & Infrastructure'},
#  {'ticker': 'ALB',
#   'company name': 'Albemarle Corporation',
#   'sektor': 'Specialty Chemicals'},
#  {'ticker': 'ARE',
#   'company name': 'Alexandria Real Estate Equities',
#   'sektor': 'Office REITs'},
#  {'ticker': 'ALGN',
#   'company name': 'Align Technology',
#   'sektor': 'Health Care Supplies'},
#  {'ticker': 'ALLE', 'company name': 'Allegion', 'sektor': 'Building Products'},
#  {'ticker': 'LNT',
#   'company name': 'Alliant Energy',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'ALL',
#   'company name': 'Allstate',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'GOOGL',
#   'company name': 'Alphabet Inc. (Class A)',
#   'sektor': 'Interactive Media & Services'},
#  {'ticker': 'GOOG',
#   'company name': 'Alphabet Inc. (Class C)',
#   'sektor': 'Interactive Media & Services'},
#  {'ticker': 'MO', 'company name': 'Altria', 'sektor': 'Tobacco'},
#  {'ticker': 'AMZN', 'company name': 'Amazon', 'sektor': 'Broadline Retail'},
#  {'ticker': 'AMCR',
#   'company name': 'Amcor',
#   'sektor': 'Paper & Plastic Packaging Products & Materials'},
#  {'ticker': 'AEE', 'company name': 'Ameren', 'sektor': 'Multi-Utilities'},
#  {'ticker': 'AAL',
#   'company name': 'American Airlines Group',
#   'sektor': 'Passenger Airlines'},
#  {'ticker': 'AEP',
#   'company name': 'American Electric Power',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'AXP',
#   'company name': 'American Express',
#   'sektor': 'Consumer Finance'},
#  {'ticker': 'AIG',
#   'company name': 'American International Group',
#   'sektor': 'Multi-line Insurance'},
#  {'ticker': 'AMT',
#   'company name': 'American Tower',
#   'sektor': 'Telecom Tower REITs'},
#  {'ticker': 'AWK',
#   'company name': 'American Water Works',
#   'sektor': 'Water Utilities'},
#  {'ticker': 'AMP',
#   'company name': 'Ameriprise Financial',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'AME',
#   'company name': 'Ametek',
#   'sektor': 'Electrical Components & Equipment'},
#  {'ticker': 'AMGN', 'company name': 'Amgen', 'sektor': 'Biotechnology'},
#  {'ticker': 'APH',
#   'company name': 'Amphenol',
#   'sektor': 'Electronic Components'},
#  {'ticker': 'ADI',
#   'company name': 'Analog Devices',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'ANSS', 'company name': 'Ansys', 'sektor': 'Application Software'},
#  {'ticker': 'AON', 'company name': 'Aon', 'sektor': 'Insurance Brokers'},
#  {'ticker': 'APA',
#   'company name': 'APA Corporation',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'AAPL',
#   'company name': 'Apple Inc.',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'AMAT',
#   'company name': 'Applied Materials',
#   'sektor': 'Semiconductor Materials & Equipment'},
#  {'ticker': 'APTV',
#   'company name': 'Aptiv',
#   'sektor': 'Automotive Parts & Equipment'},
#  {'ticker': 'ACGL',
#   'company name': 'Arch Capital Group',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'ADM',
#   'company name': 'Archer Daniels Midland',
#   'sektor': 'Agricultural Products & Services'},
#  {'ticker': 'ANET',
#   'company name': 'Arista Networks',
#   'sektor': 'Communications Equipment'},
#  {'ticker': 'AJG',
#   'company name': 'Arthur J. Gallagher & Co.',
#   'sektor': 'Insurance Brokers'},
#  {'ticker': 'AIZ',
#   'company name': 'Assurant',
#   'sektor': 'Multi-line Insurance'},
#  {'ticker': 'T',
#   'company name': 'AT&T',
#   'sektor': 'Integrated Telecommunication Services'},
#  {'ticker': 'ATO', 'company name': 'Atmos Energy', 'sektor': 'Gas Utilities'},
#  {'ticker': 'ADSK',
#   'company name': 'Autodesk',
#   'sektor': 'Application Software'},
#  {'ticker': 'ADP',
#   'company name': 'Automatic Data Processing',
#   'sektor': 'Human Resource & Employment Services'},
#  {'ticker': 'AZO', 'company name': 'AutoZone', 'sektor': 'Automotive Retail'},
#  {'ticker': 'AVB',
#   'company name': 'AvalonBay Communities',
#   'sektor': 'Multi-Family Residential REITs'},
#  {'ticker': 'AVY',
#   'company name': 'Avery Dennison',
#   'sektor': 'Paper & Plastic Packaging Products & Materials'},
#  {'ticker': 'AXON',
#   'company name': 'Axon Enterprise',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'BKR',
#   'company name': 'Baker Hughes',
#   'sektor': 'Oil & Gas Equipment & Services'},
#  {'ticker': 'BALL',
#   'company name': 'Ball Corporation',
#   'sektor': 'Metal, Glass & Plastic Containers'},
#  {'ticker': 'BAC',
#   'company name': 'Bank of America',
#   'sektor': 'Diversified Banks'},
#  {'ticker': 'BK',
#   'company name': 'BNY Mellon',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'BBWI',
#   'company name': 'Bath & Body Works, Inc.',
#   'sektor': 'Other Specialty Retail'},
#  {'ticker': 'BAX',
#   'company name': 'Baxter International',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'BDX',
#   'company name': 'Becton Dickinson',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'BRK.B',
#   'company name': 'Berkshire Hathaway',
#   'sektor': 'Multi-Sector Holdings'},
#  {'ticker': 'BBY',
#   'company name': 'Best Buy',
#   'sektor': 'Computer & Electronics Retail'},
#  {'ticker': 'BIO',
#   'company name': 'Bio-Rad Laboratories',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'TECH',
#   'company name': 'Bio-Techne',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'BIIB', 'company name': 'Biogen', 'sektor': 'Biotechnology'},
#  {'ticker': 'BLK',
#   'company name': 'BlackRock',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'BX',
#   'company name': 'Blackstone Inc.',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'BA', 'company name': 'Boeing', 'sektor': 'Aerospace & Defense'},
#  {'ticker': 'BKNG',
#   'company name': 'Booking Holdings',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'BWA',
#   'company name': 'BorgWarner',
#   'sektor': 'Automotive Parts & Equipment'},
#  {'ticker': 'BSX',
#   'company name': 'Boston Scientific',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'BMY',
#   'company name': 'Bristol Myers Squibb',
#   'sektor': 'Pharmaceuticals'},
#  {'ticker': 'AVGO', 'company name': 'Broadcom', 'sektor': 'Semiconductors'},
#  {'ticker': 'BR',
#   'company name': 'Broadridge Financial Solutions',
#   'sektor': 'Data Processing & Outsourced Services'},
#  {'ticker': 'BRO',
#   'company name': 'Brown & Brown',
#   'sektor': 'Insurance Brokers'},
#  {'ticker': 'BF.B',
#   'company name': 'Brown–Forman',
#   'sektor': 'Distillers & Vintners'},
#  {'ticker': 'BLDR',
#   'company name': 'Builders FirstSource',
#   'sektor': 'Building Products'},
#  {'ticker': 'BG',
#   'company name': 'Bunge Global',
#   'sektor': 'Agricultural Products & Services'},
#  {'ticker': 'BXP', 'company name': 'BXP, Inc.', 'sektor': 'Office REITs'},
#  {'ticker': 'CHRW',
#   'company name': 'C.H. Robinson',
#   'sektor': 'Air Freight & Logistics'},
#  {'ticker': 'CDNS',
#   'company name': 'Cadence Design Systems',
#   'sektor': 'Application Software'},
#  {'ticker': 'CZR',
#   'company name': 'Caesars Entertainment',
#   'sektor': 'Casinos & Gaming'},
#  {'ticker': 'CPT',
#   'company name': 'Camden Property Trust',
#   'sektor': 'Multi-Family Residential REITs'},
#  {'ticker': 'CPB',
#   'company name': 'Campbell Soup Company',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'COF',
#   'company name': 'Capital One',
#   'sektor': 'Consumer Finance'},
#  {'ticker': 'CAH',
#   'company name': 'Cardinal Health',
#   'sektor': 'Health Care Distributors'},
#  {'ticker': 'KMX', 'company name': 'CarMax', 'sektor': 'Automotive Retail'},
#  {'ticker': 'CCL',
#   'company name': 'Carnival',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'CARR',
#   'company name': 'Carrier Global',
#   'sektor': 'Building Products'},
#  {'ticker': 'CTLT', 'company name': 'Catalent', 'sektor': 'Pharmaceuticals'},
#  {'ticker': 'CAT',
#   'company name': 'Caterpillar Inc.',
#   'sektor': 'Construction Machinery & Heavy Transportation Equipment'},
#  {'ticker': 'CBOE',
#   'company name': 'Cboe Global Markets',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'CBRE',
#   'company name': 'CBRE Group',
#   'sektor': 'Real Estate Services'},
#  {'ticker': 'CDW', 'company name': 'CDW', 'sektor': 'Technology Distributors'},
#  {'ticker': 'CE', 'company name': 'Celanese', 'sektor': 'Specialty Chemicals'},
#  {'ticker': 'COR',
#   'company name': 'Cencora',
#   'sektor': 'Health Care Distributors'},
#  {'ticker': 'CNC',
#   'company name': 'Centene Corporation',
#   'sektor': 'Managed Health Care'},
#  {'ticker': 'CNP',
#   'company name': 'CenterPoint Energy',
#   'sektor': 'Multi-Utilities'},
#  {'ticker': 'CF',
#   'company name': 'CF Industries',
#   'sektor': 'Fertilizers & Agricultural Chemicals'},
#  {'ticker': 'CRL',
#   'company name': 'Charles River Laboratories',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'SCHW',
#   'company name': 'Charles Schwab Corporation',
#   'sektor': 'Investment Banking & Brokerage'},
#  {'ticker': 'CHTR',
#   'company name': 'Charter Communications',
#   'sektor': 'Cable & Satellite'},
#  {'ticker': 'CVX',
#   'company name': 'Chevron Corporation',
#   'sektor': 'Integrated Oil & Gas'},
#  {'ticker': 'CMG',
#   'company name': 'Chipotle Mexican Grill',
#   'sektor': 'Restaurants'},
#  {'ticker': 'CB',
#   'company name': 'Chubb Limited',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'CHD',
#   'company name': 'Church & Dwight',
#   'sektor': 'Household Products'},
#  {'ticker': 'CI', 'company name': 'Cigna', 'sektor': 'Health Care Services'},
#  {'ticker': 'CINF',
#   'company name': 'Cincinnati Financial',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'CTAS',
#   'company name': 'Cintas',
#   'sektor': 'Diversified Support Services'},
#  {'ticker': 'CSCO',
#   'company name': 'Cisco',
#   'sektor': 'Communications Equipment'},
#  {'ticker': 'C', 'company name': 'Citigroup', 'sektor': 'Diversified Banks'},
#  {'ticker': 'CFG',
#   'company name': 'Citizens Financial Group',
#   'sektor': 'Regional Banks'},
#  {'ticker': 'CLX', 'company name': 'Clorox', 'sektor': 'Household Products'},
#  {'ticker': 'CME',
#   'company name': 'CME Group',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'CMS', 'company name': 'CMS Energy', 'sektor': 'Multi-Utilities'},
#  {'ticker': 'KO',
#   'company name': 'Coca-Cola Company (The)',
#   'sektor': 'Soft Drinks & Non-alcoholic Beverages'},
#  {'ticker': 'CTSH',
#   'company name': 'Cognizant',
#   'sektor': 'IT Consulting & Other Services'},
#  {'ticker': 'CL',
#   'company name': 'Colgate-Palmolive',
#   'sektor': 'Household Products'},
#  {'ticker': 'CMCSA', 'company name': 'Comcast', 'sektor': 'Cable & Satellite'},
#  {'ticker': 'CAG',
#   'company name': 'Conagra Brands',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'COP',
#   'company name': 'ConocoPhillips',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'ED',
#   'company name': 'Consolidated Edison',
#   'sektor': 'Multi-Utilities'},
#  {'ticker': 'STZ',
#   'company name': 'Constellation Brands',
#   'sektor': 'Distillers & Vintners'},
#  {'ticker': 'CEG',
#   'company name': 'Constellation Energy',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'COO',
#   'company name': 'Cooper Companies (The)',
#   'sektor': 'Health Care Supplies'},
#  {'ticker': 'CPRT',
#   'company name': 'Copart',
#   'sektor': 'Diversified Support Services'},
#  {'ticker': 'GLW',
#   'company name': 'Corning Inc.',
#   'sektor': 'Electronic Components'},
#  {'ticker': 'CPAY',
#   'company name': 'Corpay',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'CTVA',
#   'company name': 'Corteva',
#   'sektor': 'Fertilizers & Agricultural Chemicals'},
#  {'ticker': 'CSGP',
#   'company name': 'CoStar Group',
#   'sektor': 'Real Estate Services'},
#  {'ticker': 'COST',
#   'company name': 'Costco',
#   'sektor': 'Consumer Staples Merchandise Retail'},
#  {'ticker': 'CTRA',
#   'company name': 'Coterra',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'CRWD',
#   'company name': 'CrowdStrike',
#   'sektor': 'Systems Software'},
#  {'ticker': 'CCI',
#   'company name': 'Crown Castle',
#   'sektor': 'Telecom Tower REITs'},
#  {'ticker': 'CSX',
#   'company name': 'CSX Corporation',
#   'sektor': 'Rail Transportation'},
#  {'ticker': 'CMI',
#   'company name': 'Cummins',
#   'sektor': 'Construction Machinery & Heavy Transportation Equipment'},
#  {'ticker': 'CVS',
#   'company name': 'CVS Health',
#   'sektor': 'Health Care Services'},
#  {'ticker': 'DHR',
#   'company name': 'Danaher Corporation',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'DRI',
#   'company name': 'Darden Restaurants',
#   'sektor': 'Restaurants'},
#  {'ticker': 'DVA', 'company name': 'DaVita', 'sektor': 'Health Care Services'},
#  {'ticker': 'DAY',
#   'company name': 'Dayforce',
#   'sektor': 'Human Resource & Employment Services'},
#  {'ticker': 'DECK', 'company name': 'Deckers Brands', 'sektor': 'Footwear'},
#  {'ticker': 'DE',
#   'company name': 'Deere & Company',
#   'sektor': 'Agricultural & Farm Machinery'},
#  {'ticker': 'DAL',
#   'company name': 'Delta Air Lines',
#   'sektor': 'Passenger Airlines'},
#  {'ticker': 'DVN',
#   'company name': 'Devon Energy',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'DXCM',
#   'company name': 'Dexcom',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'FANG',
#   'company name': 'Diamondback Energy',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'DLR',
#   'company name': 'Digital Realty',
#   'sektor': 'Data Center REITs'},
#  {'ticker': 'DFS',
#   'company name': 'Discover Financial',
#   'sektor': 'Consumer Finance'},
#  {'ticker': 'DG',
#   'company name': 'Dollar General',
#   'sektor': 'Consumer Staples Merchandise Retail'},
#  {'ticker': 'DLTR',
#   'company name': 'Dollar Tree',
#   'sektor': 'Consumer Staples Merchandise Retail'},
#  {'ticker': 'D',
#   'company name': 'Dominion Energy',
#   'sektor': 'Multi-Utilities'},
#  {'ticker': 'DPZ', 'company name': "Domino's", 'sektor': 'Restaurants'},
#  {'ticker': 'DOV',
#   'company name': 'Dover Corporation',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'DOW',
#   'company name': 'Dow Inc.',
#   'sektor': 'Commodity Chemicals'},
#  {'ticker': 'DHI', 'company name': 'DR Horton', 'sektor': 'Homebuilding'},
#  {'ticker': 'DTE', 'company name': 'DTE Energy', 'sektor': 'Multi-Utilities'},
#  {'ticker': 'DUK',
#   'company name': 'Duke Energy',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'DD', 'company name': 'DuPont', 'sektor': 'Specialty Chemicals'},
#  {'ticker': 'EMN',
#   'company name': 'Eastman Chemical Company',
#   'sektor': 'Specialty Chemicals'},
#  {'ticker': 'ETN',
#   'company name': 'Eaton Corporation',
#   'sektor': 'Electrical Components & Equipment'},
#  {'ticker': 'EBAY', 'company name': 'eBay', 'sektor': 'Broadline Retail'},
#  {'ticker': 'ECL', 'company name': 'Ecolab', 'sektor': 'Specialty Chemicals'},
#  {'ticker': 'EIX',
#   'company name': 'Edison International',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'EW',
#   'company name': 'Edwards Lifesciences',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'EA',
#   'company name': 'Electronic Arts',
#   'sektor': 'Interactive Home Entertainment'},
#  {'ticker': 'ELV',
#   'company name': 'Elevance Health',
#   'sektor': 'Managed Health Care'},
#  {'ticker': 'EMR',
#   'company name': 'Emerson Electric',
#   'sektor': 'Electrical Components & Equipment'},
#  {'ticker': 'ENPH',
#   'company name': 'Enphase',
#   'sektor': 'Semiconductor Materials & Equipment'},
#  {'ticker': 'ETR', 'company name': 'Entergy', 'sektor': 'Electric Utilities'},
#  {'ticker': 'EOG',
#   'company name': 'EOG Resources',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'EPAM',
#   'company name': 'EPAM Systems',
#   'sektor': 'IT Consulting & Other Services'},
#  {'ticker': 'EQT',
#   'company name': 'EQT Corporation',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'EFX',
#   'company name': 'Equifax',
#   'sektor': 'Research & Consulting Services'},
#  {'ticker': 'EQIX', 'company name': 'Equinix', 'sektor': 'Data Center REITs'},
#  {'ticker': 'EQR',
#   'company name': 'Equity Residential',
#   'sektor': 'Multi-Family Residential REITs'},
#  {'ticker': 'ESS',
#   'company name': 'Essex Property Trust',
#   'sektor': 'Multi-Family Residential REITs'},
#  {'ticker': 'EL',
#   'company name': 'Estée Lauder Companies (The)',
#   'sektor': 'Personal Care Products'},
#  {'ticker': 'ETSY', 'company name': 'Etsy', 'sektor': 'Broadline Retail'},
#  {'ticker': 'EG', 'company name': 'Everest Group', 'sektor': 'Reinsurance'},
#  {'ticker': 'EVRG', 'company name': 'Evergy', 'sektor': 'Electric Utilities'},
#  {'ticker': 'ES',
#   'company name': 'Eversource',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'EXC', 'company name': 'Exelon', 'sektor': 'Electric Utilities'},
#  {'ticker': 'EXPE',
#   'company name': 'Expedia Group',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'EXPD',
#   'company name': 'Expeditors International',
#   'sektor': 'Air Freight & Logistics'},
#  {'ticker': 'EXR',
#   'company name': 'Extra Space Storage',
#   'sektor': 'Self-Storage REITs'},
#  {'ticker': 'XOM',
#   'company name': 'ExxonMobil',
#   'sektor': 'Integrated Oil & Gas'},
#  {'ticker': 'FFIV',
#   'company name': 'F5, Inc.',
#   'sektor': 'Communications Equipment'},
#  {'ticker': 'FDS',
#   'company name': 'FactSet',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'FICO',
#   'company name': 'Fair Isaac',
#   'sektor': 'Application Software'},
#  {'ticker': 'FAST',
#   'company name': 'Fastenal',
#   'sektor': 'Trading Companies & Distributors'},
#  {'ticker': 'FRT', 'company name': 'Federal Realty', 'sektor': 'Retail REITs'},
#  {'ticker': 'FDX',
#   'company name': 'FedEx',
#   'sektor': 'Air Freight & Logistics'},
#  {'ticker': 'FIS',
#   'company name': 'Fidelity National Information Services',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'FITB',
#   'company name': 'Fifth Third Bank',
#   'sektor': 'Diversified Banks'},
#  {'ticker': 'FSLR', 'company name': 'First Solar', 'sektor': 'Semiconductors'},
#  {'ticker': 'FE',
#   'company name': 'FirstEnergy',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'FI',
#   'company name': 'Fiserv',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'FMC',
#   'company name': 'FMC Corporation',
#   'sektor': 'Fertilizers & Agricultural Chemicals'},
#  {'ticker': 'F',
#   'company name': 'Ford Motor Company',
#   'sektor': 'Automobile Manufacturers'},
#  {'ticker': 'FTNT', 'company name': 'Fortinet', 'sektor': 'Systems Software'},
#  {'ticker': 'FTV',
#   'company name': 'Fortive',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'FOXA',
#   'company name': 'Fox Corporation (Class A)',
#   'sektor': 'Broadcasting'},
#  {'ticker': 'FOX',
#   'company name': 'Fox Corporation (Class B)',
#   'sektor': 'Broadcasting'},
#  {'ticker': 'BEN',
#   'company name': 'Franklin Templeton',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'FCX', 'company name': 'Freeport-McMoRan', 'sektor': 'Copper'},
#  {'ticker': 'GRMN',
#   'company name': 'Garmin',
#   'sektor': 'Consumer Electronics'},
#  {'ticker': 'IT',
#   'company name': 'Gartner',
#   'sektor': 'IT Consulting & Other Services'},
#  {'ticker': 'GE',
#   'company name': 'GE Aerospace',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'GEHC',
#   'company name': 'GE HealthCare',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'GEV',
#   'company name': 'GE Vernova',
#   'sektor': 'Heavy Electrical Equipment'},
#  {'ticker': 'GEN',
#   'company name': 'Gen Digital',
#   'sektor': 'Systems Software'},
#  {'ticker': 'GNRC',
#   'company name': 'Generac',
#   'sektor': 'Electrical Components & Equipment'},
#  {'ticker': 'GD',
#   'company name': 'General Dynamics',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'GIS',
#   'company name': 'General Mills',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'GM',
#   'company name': 'General Motors',
#   'sektor': 'Automobile Manufacturers'},
#  {'ticker': 'GPC',
#   'company name': 'Genuine Parts Company',
#   'sektor': 'Distributors'},
#  {'ticker': 'GILD',
#   'company name': 'Gilead Sciences',
#   'sektor': 'Biotechnology'},
#  {'ticker': 'GPN',
#   'company name': 'Global Payments',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'GL',
#   'company name': 'Globe Life',
#   'sektor': 'Life & Health Insurance'},
#  {'ticker': 'GDDY',
#   'company name': 'GoDaddy',
#   'sektor': 'Internet Services & Infrastructure'},
#  {'ticker': 'GS',
#   'company name': 'Goldman Sachs',
#   'sektor': 'Investment Banking & Brokerage'},
#  {'ticker': 'HAL',
#   'company name': 'Halliburton',
#   'sektor': 'Oil & Gas Equipment & Services'},
#  {'ticker': 'HIG',
#   'company name': 'Hartford (The)',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'HAS', 'company name': 'Hasbro', 'sektor': 'Leisure Products'},
#  {'ticker': 'HCA',
#   'company name': 'HCA Healthcare',
#   'sektor': 'Health Care Facilities'},
#  {'ticker': 'DOC',
#   'company name': 'Healthpeak Properties',
#   'sektor': 'Health Care REITs'},
#  {'ticker': 'HSIC',
#   'company name': 'Henry Schein',
#   'sektor': 'Health Care Distributors'},
#  {'ticker': 'HSY',
#   'company name': 'Hershey Company (The)',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'HES',
#   'company name': 'Hess Corporation',
#   'sektor': 'Integrated Oil & Gas'},
#  {'ticker': 'HPE',
#   'company name': 'Hewlett Packard Enterprise',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'HLT',
#   'company name': 'Hilton Worldwide',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'HOLX',
#   'company name': 'Hologic',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'HD',
#   'company name': 'Home Depot (The)',
#   'sektor': 'Home Improvement Retail'},
#  {'ticker': 'HON',
#   'company name': 'Honeywell',
#   'sektor': 'Industrial Conglomerates'},
#  {'ticker': 'HRL',
#   'company name': 'Hormel Foods',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'HST',
#   'company name': 'Host Hotels & Resorts',
#   'sektor': 'Hotel & Resort REITs'},
#  {'ticker': 'HWM',
#   'company name': 'Howmet Aerospace',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'HPQ',
#   'company name': 'HP Inc.',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'HUBB',
#   'company name': 'Hubbell Incorporated',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'HUM', 'company name': 'Humana', 'sektor': 'Managed Health Care'},
#  {'ticker': 'HBAN',
#   'company name': 'Huntington Bancshares',
#   'sektor': 'Regional Banks'},
#  {'ticker': 'HII',
#   'company name': 'Huntington Ingalls Industries',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'IBM',
#   'company name': 'IBM',
#   'sektor': 'IT Consulting & Other Services'},
#  {'ticker': 'IEX',
#   'company name': 'IDEX Corporation',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'IDXX',
#   'company name': 'Idexx Laboratories',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'ITW',
#   'company name': 'Illinois Tool Works',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'INCY', 'company name': 'Incyte', 'sektor': 'Biotechnology'},
#  {'ticker': 'IR',
#   'company name': 'Ingersoll Rand',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'PODD',
#   'company name': 'Insulet Corporation',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'INTC', 'company name': 'Intel', 'sektor': 'Semiconductors'},
#  {'ticker': 'ICE',
#   'company name': 'Intercontinental Exchange',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'IFF',
#   'company name': 'International Flavors & Fragrances',
#   'sektor': 'Specialty Chemicals'},
#  {'ticker': 'IP',
#   'company name': 'International Paper',
#   'sektor': 'Paper & Plastic Packaging Products & Materials'},
#  {'ticker': 'IPG',
#   'company name': 'Interpublic Group of Companies (The)',
#   'sektor': 'Advertising'},
#  {'ticker': 'INTU',
#   'company name': 'Intuit',
#   'sektor': 'Application Software'},
#  {'ticker': 'ISRG',
#   'company name': 'Intuitive Surgical',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'IVZ',
#   'company name': 'Invesco',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'INVH',
#   'company name': 'Invitation Homes',
#   'sektor': 'Single-Family Residential REITs'},
#  {'ticker': 'IQV',
#   'company name': 'IQVIA',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'IRM',
#   'company name': 'Iron Mountain',
#   'sektor': 'Other Specialized REITs'},
#  {'ticker': 'JBHT',
#   'company name': 'J.B. Hunt',
#   'sektor': 'Cargo Ground Transportation'},
#  {'ticker': 'JBL',
#   'company name': 'Jabil',
#   'sektor': 'Electronic Manufacturing Services'},
#  {'ticker': 'JKHY',
#   'company name': 'Jack Henry & Associates',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'J',
#   'company name': 'Jacobs Solutions',
#   'sektor': 'Construction & Engineering'},
#  {'ticker': 'JNJ',
#   'company name': 'Johnson & Johnson',
#   'sektor': 'Pharmaceuticals'},
#  {'ticker': 'JCI',
#   'company name': 'Johnson Controls',
#   'sektor': 'Building Products'},
#  {'ticker': 'JPM',
#   'company name': 'JPMorgan Chase',
#   'sektor': 'Diversified Banks'},
#  {'ticker': 'JNPR',
#   'company name': 'Juniper Networks',
#   'sektor': 'Communications Equipment'},
#  {'ticker': 'K',
#   'company name': 'Kellanova',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'KVUE',
#   'company name': 'Kenvue',
#   'sektor': 'Personal Care Products'},
#  {'ticker': 'KDP',
#   'company name': 'Keurig Dr Pepper',
#   'sektor': 'Soft Drinks & Non-alcoholic Beverages'},
#  {'ticker': 'KEY', 'company name': 'KeyCorp', 'sektor': 'Regional Banks'},
#  {'ticker': 'KEYS',
#   'company name': 'Keysight',
#   'sektor': 'Electronic Equipment & Instruments'},
#  {'ticker': 'KMB',
#   'company name': 'Kimberly-Clark',
#   'sektor': 'Household Products'},
#  {'ticker': 'KIM', 'company name': 'Kimco Realty', 'sektor': 'Retail REITs'},
#  {'ticker': 'KMI',
#   'company name': 'Kinder Morgan',
#   'sektor': 'Oil & Gas Storage & Transportation'},
#  {'ticker': 'KKR',
#   'company name': 'KKR',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'KLAC',
#   'company name': 'KLA Corporation',
#   'sektor': 'Semiconductor Materials & Equipment'},
#  {'ticker': 'KHC',
#   'company name': 'Kraft Heinz',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'KR', 'company name': 'Kroger', 'sektor': 'Food Retail'},
#  {'ticker': 'LHX',
#   'company name': 'L3Harris',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'LH', 'company name': 'LabCorp', 'sektor': 'Health Care Services'},
#  {'ticker': 'LRCX',
#   'company name': 'Lam Research',
#   'sektor': 'Semiconductor Materials & Equipment'},
#  {'ticker': 'LW',
#   'company name': 'Lamb Weston',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'LVS',
#   'company name': 'Las Vegas Sands',
#   'sektor': 'Casinos & Gaming'},
#  {'ticker': 'LDOS',
#   'company name': 'Leidos',
#   'sektor': 'Diversified Support Services'},
#  {'ticker': 'LEN', 'company name': 'Lennar', 'sektor': 'Homebuilding'},
#  {'ticker': 'LLY', 'company name': 'Lilly (Eli)', 'sektor': 'Pharmaceuticals'},
#  {'ticker': 'LIN', 'company name': 'Linde plc', 'sektor': 'Industrial Gases'},
#  {'ticker': 'LYV',
#   'company name': 'Live Nation Entertainment',
#   'sektor': 'Movies & Entertainment'},
#  {'ticker': 'LKQ',
#   'company name': 'LKQ Corporation',
#   'sektor': 'Distributors'},
#  {'ticker': 'LMT',
#   'company name': 'Lockheed Martin',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'L',
#   'company name': 'Loews Corporation',
#   'sektor': 'Multi-line Insurance'},
#  {'ticker': 'LOW',
#   'company name': "Lowe's",
#   'sektor': 'Home Improvement Retail'},
#  {'ticker': 'LULU',
#   'company name': 'Lululemon Athletica',
#   'sektor': 'Apparel, Accessories & Luxury Goods'},
#  {'ticker': 'LYB',
#   'company name': 'LyondellBasell',
#   'sektor': 'Specialty Chemicals'},
#  {'ticker': 'MTB', 'company name': 'M&T Bank', 'sektor': 'Regional Banks'},
#  {'ticker': 'MRO',
#   'company name': 'Marathon Oil',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'MPC',
#   'company name': 'Marathon Petroleum',
#   'sektor': 'Oil & Gas Refining & Marketing'},
#  {'ticker': 'MKTX',
#   'company name': 'MarketAxess',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'MAR',
#   'company name': 'Marriott International',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'MMC',
#   'company name': 'Marsh McLennan',
#   'sektor': 'Insurance Brokers'},
#  {'ticker': 'MLM',
#   'company name': 'Martin Marietta Materials',
#   'sektor': 'Construction Materials'},
#  {'ticker': 'MAS', 'company name': 'Masco', 'sektor': 'Building Products'},
#  {'ticker': 'MA',
#   'company name': 'Mastercard',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'MTCH',
#   'company name': 'Match Group',
#   'sektor': 'Interactive Media & Services'},
#  {'ticker': 'MKC',
#   'company name': 'McCormick & Company',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'MCD', 'company name': "McDonald's", 'sektor': 'Restaurants'},
#  {'ticker': 'MCK',
#   'company name': 'McKesson Corporation',
#   'sektor': 'Health Care Distributors'},
#  {'ticker': 'MDT',
#   'company name': 'Medtronic',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'MRK', 'company name': 'Merck & Co.', 'sektor': 'Pharmaceuticals'},
#  {'ticker': 'META',
#   'company name': 'Meta Platforms',
#   'sektor': 'Interactive Media & Services'},
#  {'ticker': 'MET',
#   'company name': 'MetLife',
#   'sektor': 'Life & Health Insurance'},
#  {'ticker': 'MTD',
#   'company name': 'Mettler Toledo',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'MGM',
#   'company name': 'MGM Resorts',
#   'sektor': 'Casinos & Gaming'},
#  {'ticker': 'MCHP',
#   'company name': 'Microchip Technology',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'MU',
#   'company name': 'Micron Technology',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'MSFT', 'company name': 'Microsoft', 'sektor': 'Systems Software'},
#  {'ticker': 'MAA',
#   'company name': 'Mid-America Apartment Communities',
#   'sektor': 'Multi-Family Residential REITs'},
#  {'ticker': 'MRNA', 'company name': 'Moderna', 'sektor': 'Biotechnology'},
#  {'ticker': 'MHK',
#   'company name': 'Mohawk Industries',
#   'sektor': 'Home Furnishings'},
#  {'ticker': 'MOH',
#   'company name': 'Molina Healthcare',
#   'sektor': 'Managed Health Care'},
#  {'ticker': 'TAP',
#   'company name': 'Molson Coors Beverage Company',
#   'sektor': 'Brewers'},
#  {'ticker': 'MDLZ',
#   'company name': 'Mondelez International',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'MPWR',
#   'company name': 'Monolithic Power Systems',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'MNST',
#   'company name': 'Monster Beverage',
#   'sektor': 'Soft Drinks & Non-alcoholic Beverages'},
#  {'ticker': 'MCO',
#   'company name': "Moody's Corporation",
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'MS',
#   'company name': 'Morgan Stanley',
#   'sektor': 'Investment Banking & Brokerage'},
#  {'ticker': 'MOS',
#   'company name': 'Mosaic Company (The)',
#   'sektor': 'Fertilizers & Agricultural Chemicals'},
#  {'ticker': 'MSI',
#   'company name': 'Motorola Solutions',
#   'sektor': 'Communications Equipment'},
#  {'ticker': 'MSCI',
#   'company name': 'MSCI',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'NDAQ',
#   'company name': 'Nasdaq, Inc.',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'NTAP',
#   'company name': 'NetApp',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'NFLX',
#   'company name': 'Netflix',
#   'sektor': 'Movies & Entertainment'},
#  {'ticker': 'NEM', 'company name': 'Newmont', 'sektor': 'Gold'},
#  {'ticker': 'NWSA',
#   'company name': 'News Corp (Class A)',
#   'sektor': 'Publishing'},
#  {'ticker': 'NWS',
#   'company name': 'News Corp (Class B)',
#   'sektor': 'Publishing'},
#  {'ticker': 'NEE',
#   'company name': 'NextEra Energy',
#   'sektor': 'Multi-Utilities'},
#  {'ticker': 'NKE',
#   'company name': 'Nike, Inc.',
#   'sektor': 'Apparel, Accessories & Luxury Goods'},
#  {'ticker': 'NI', 'company name': 'NiSource', 'sektor': 'Multi-Utilities'},
#  {'ticker': 'NDSN',
#   'company name': 'Nordson Corporation',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'NSC',
#   'company name': 'Norfolk Southern Railway',
#   'sektor': 'Rail Transportation'},
#  {'ticker': 'NTRS',
#   'company name': 'Northern Trust',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'NOC',
#   'company name': 'Northrop Grumman',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'NCLH',
#   'company name': 'Norwegian Cruise Line Holdings',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'NRG',
#   'company name': 'NRG Energy',
#   'sektor': 'Independent Power Producers & Energy Traders'},
#  {'ticker': 'NUE', 'company name': 'Nucor', 'sektor': 'Steel'},
#  {'ticker': 'NVDA', 'company name': 'Nvidia', 'sektor': 'Semiconductors'},
#  {'ticker': 'NVR', 'company name': 'NVR, Inc.', 'sektor': 'Homebuilding'},
#  {'ticker': 'NXPI',
#   'company name': 'NXP Semiconductors',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'ORLY',
#   'company name': "O'Reilly Auto Parts",
#   'sektor': 'Automotive Retail'},
#  {'ticker': 'OXY',
#   'company name': 'Occidental Petroleum',
#   'sektor': 'Oil & Gas Exploration & Production'},
#  {'ticker': 'ODFL',
#   'company name': 'Old Dominion',
#   'sektor': 'Cargo Ground Transportation'},
#  {'ticker': 'OMC', 'company name': 'Omnicom Group', 'sektor': 'Advertising'},
#  {'ticker': 'ON',
#   'company name': 'ON Semiconductor',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'OKE',
#   'company name': 'ONEOK',
#   'sektor': 'Oil & Gas Storage & Transportation'},
#  {'ticker': 'ORCL',
#   'company name': 'Oracle Corporation',
#   'sektor': 'Application Software'},
#  {'ticker': 'OTIS',
#   'company name': 'Otis Worldwide',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'PCAR',
#   'company name': 'Paccar',
#   'sektor': 'Construction Machinery & Heavy Transportation Equipment'},
#  {'ticker': 'PKG',
#   'company name': 'Packaging Corporation of America',
#   'sektor': 'Paper & Plastic Packaging Products & Materials'},
#  {'ticker': 'PANW',
#   'company name': 'Palo Alto Networks',
#   'sektor': 'Systems Software'},
#  {'ticker': 'PARA',
#   'company name': 'Paramount Global',
#   'sektor': 'Movies & Entertainment'},
#  {'ticker': 'PH',
#   'company name': 'Parker Hannifin',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'PAYX',
#   'company name': 'Paychex',
#   'sektor': 'Human Resource & Employment Services'},
#  {'ticker': 'PAYC',
#   'company name': 'Paycom',
#   'sektor': 'Human Resource & Employment Services'},
#  {'ticker': 'PYPL',
#   'company name': 'PayPal',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'PNR',
#   'company name': 'Pentair',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'PEP',
#   'company name': 'PepsiCo',
#   'sektor': 'Soft Drinks & Non-alcoholic Beverages'},
#  {'ticker': 'PFE', 'company name': 'Pfizer', 'sektor': 'Pharmaceuticals'},
#  {'ticker': 'PCG',
#   'company name': 'PG&E Corporation',
#   'sektor': 'Multi-Utilities'},
#  {'ticker': 'PM',
#   'company name': 'Philip Morris International',
#   'sektor': 'Tobacco'},
#  {'ticker': 'PSX',
#   'company name': 'Phillips 66',
#   'sektor': 'Oil & Gas Refining & Marketing'},
#  {'ticker': 'PNW',
#   'company name': 'Pinnacle West',
#   'sektor': 'Multi-Utilities'},
#  {'ticker': 'PNC',
#   'company name': 'PNC Financial Services',
#   'sektor': 'Regional Banks'},
#  {'ticker': 'POOL',
#   'company name': 'Pool Corporation',
#   'sektor': 'Distributors'},
#  {'ticker': 'PPG',
#   'company name': 'PPG Industries',
#   'sektor': 'Specialty Chemicals'},
#  {'ticker': 'PPL',
#   'company name': 'PPL Corporation',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'PFG',
#   'company name': 'Principal Financial Group',
#   'sektor': 'Life & Health Insurance'},
#  {'ticker': 'PG',
#   'company name': 'Procter & Gamble',
#   'sektor': 'Personal Care Products'},
#  {'ticker': 'PGR',
#   'company name': 'Progressive Corporation',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'PLD', 'company name': 'Prologis', 'sektor': 'Industrial REITs'},
#  {'ticker': 'PRU',
#   'company name': 'Prudential Financial',
#   'sektor': 'Life & Health Insurance'},
#  {'ticker': 'PEG',
#   'company name': 'Public Service Enterprise Group',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'PTC', 'company name': 'PTC', 'sektor': 'Application Software'},
#  {'ticker': 'PSA',
#   'company name': 'Public Storage',
#   'sektor': 'Self-Storage REITs'},
#  {'ticker': 'PHM', 'company name': 'PulteGroup', 'sektor': 'Homebuilding'},
#  {'ticker': 'QRVO', 'company name': 'Qorvo', 'sektor': 'Semiconductors'},
#  {'ticker': 'PWR',
#   'company name': 'Quanta Services',
#   'sektor': 'Construction & Engineering'},
#  {'ticker': 'QCOM', 'company name': 'Qualcomm', 'sektor': 'Semiconductors'},
#  {'ticker': 'DGX',
#   'company name': 'Quest Diagnostics',
#   'sektor': 'Health Care Services'},
#  {'ticker': 'RL',
#   'company name': 'Ralph Lauren Corporation',
#   'sektor': 'Apparel, Accessories & Luxury Goods'},
#  {'ticker': 'RJF',
#   'company name': 'Raymond James',
#   'sektor': 'Investment Banking & Brokerage'},
#  {'ticker': 'RTX',
#   'company name': 'RTX Corporation',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'O', 'company name': 'Realty Income', 'sektor': 'Retail REITs'},
#  {'ticker': 'REG',
#   'company name': 'Regency Centers',
#   'sektor': 'Retail REITs'},
#  {'ticker': 'REGN', 'company name': 'Regeneron', 'sektor': 'Biotechnology'},
#  {'ticker': 'RF',
#   'company name': 'Regions Financial Corporation',
#   'sektor': 'Regional Banks'},
#  {'ticker': 'RSG',
#   'company name': 'Republic Services',
#   'sektor': 'Environmental & Facilities Services'},
#  {'ticker': 'RMD',
#   'company name': 'ResMed',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'RVTY',
#   'company name': 'Revvity',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'ROK',
#   'company name': 'Rockwell Automation',
#   'sektor': 'Electrical Components & Equipment'},
#  {'ticker': 'ROL',
#   'company name': 'Rollins, Inc.',
#   'sektor': 'Environmental & Facilities Services'},
#  {'ticker': 'ROP',
#   'company name': 'Roper Technologies',
#   'sektor': 'Electronic Equipment & Instruments'},
#  {'ticker': 'ROST', 'company name': 'Ross Stores', 'sektor': 'Apparel Retail'},
#  {'ticker': 'RCL',
#   'company name': 'Royal Caribbean Group',
#   'sektor': 'Hotels, Resorts & Cruise Lines'},
#  {'ticker': 'SPGI',
#   'company name': 'S&P Global',
#   'sektor': 'Financial Exchanges & Data'},
#  {'ticker': 'CRM',
#   'company name': 'Salesforce',
#   'sektor': 'Application Software'},
#  {'ticker': 'SBAC',
#   'company name': 'SBA Communications',
#   'sektor': 'Telecom Tower REITs'},
#  {'ticker': 'SLB',
#   'company name': 'Schlumberger',
#   'sektor': 'Oil & Gas Equipment & Services'},
#  {'ticker': 'STX',
#   'company name': 'Seagate Technology',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'SRE', 'company name': 'Sempra', 'sektor': 'Multi-Utilities'},
#  {'ticker': 'NOW', 'company name': 'ServiceNow', 'sektor': 'Systems Software'},
#  {'ticker': 'SHW',
#   'company name': 'Sherwin-Williams',
#   'sektor': 'Specialty Chemicals'},
#  {'ticker': 'SPG',
#   'company name': 'Simon Property Group',
#   'sektor': 'Retail REITs'},
#  {'ticker': 'SWKS',
#   'company name': 'Skyworks Solutions',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'SJM',
#   'company name': 'J.M. Smucker Company (The)',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'SW',
#   'company name': 'Smurfit WestRock',
#   'sektor': 'Paper & Plastic Packaging Products & Materials'},
#  {'ticker': 'SNA',
#   'company name': 'Snap-on',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'SOLV',
#   'company name': 'Solventum',
#   'sektor': 'Health Care Technology'},
#  {'ticker': 'SO',
#   'company name': 'Southern Company',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'LUV',
#   'company name': 'Southwest Airlines',
#   'sektor': 'Passenger Airlines'},
#  {'ticker': 'SWK',
#   'company name': 'Stanley Black & Decker',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'SBUX', 'company name': 'Starbucks', 'sektor': 'Restaurants'},
#  {'ticker': 'STT',
#   'company name': 'State Street Corporation',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'STLD', 'company name': 'Steel Dynamics', 'sektor': 'Steel'},
#  {'ticker': 'STE',
#   'company name': 'Steris',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'SYK',
#   'company name': 'Stryker Corporation',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'SMCI',
#   'company name': 'Supermicro',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'SYF',
#   'company name': 'Synchrony Financial',
#   'sektor': 'Consumer Finance'},
#  {'ticker': 'SNPS',
#   'company name': 'Synopsys',
#   'sektor': 'Application Software'},
#  {'ticker': 'SYY', 'company name': 'Sysco', 'sektor': 'Food Distributors'},
#  {'ticker': 'TMUS',
#   'company name': 'T-Mobile US',
#   'sektor': 'Wireless Telecommunication Services'},
#  {'ticker': 'TROW',
#   'company name': 'T. Rowe Price',
#   'sektor': 'Asset Management & Custody Banks'},
#  {'ticker': 'TTWO',
#   'company name': 'Take-Two Interactive',
#   'sektor': 'Interactive Home Entertainment'},
#  {'ticker': 'TPR',
#   'company name': 'Tapestry, Inc.',
#   'sektor': 'Apparel, Accessories & Luxury Goods'},
#  {'ticker': 'TRGP',
#   'company name': 'Targa Resources',
#   'sektor': 'Oil & Gas Storage & Transportation'},
#  {'ticker': 'TGT',
#   'company name': 'Target Corporation',
#   'sektor': 'Consumer Staples Merchandise Retail'},
#  {'ticker': 'TEL',
#   'company name': 'TE Connectivity',
#   'sektor': 'Electronic Manufacturing Services'},
#  {'ticker': 'TDY',
#   'company name': 'Teledyne Technologies',
#   'sektor': 'Electronic Equipment & Instruments'},
#  {'ticker': 'TFX',
#   'company name': 'Teleflex',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'TER',
#   'company name': 'Teradyne',
#   'sektor': 'Semiconductor Materials & Equipment'},
#  {'ticker': 'TSLA',
#   'company name': 'Tesla, Inc.',
#   'sektor': 'Automobile Manufacturers'},
#  {'ticker': 'TXN',
#   'company name': 'Texas Instruments',
#   'sektor': 'Semiconductors'},
#  {'ticker': 'TXT', 'company name': 'Textron', 'sektor': 'Aerospace & Defense'},
#  {'ticker': 'TMO',
#   'company name': 'Thermo Fisher Scientific',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'TJX',
#   'company name': 'TJX Companies',
#   'sektor': 'Apparel Retail'},
#  {'ticker': 'TSCO',
#   'company name': 'Tractor Supply',
#   'sektor': 'Other Specialty Retail'},
#  {'ticker': 'TT',
#   'company name': 'Trane Technologies',
#   'sektor': 'Building Products'},
#  {'ticker': 'TDG',
#   'company name': 'TransDigm Group',
#   'sektor': 'Aerospace & Defense'},
#  {'ticker': 'TRV',
#   'company name': 'Travelers Companies (The)',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'TRMB',
#   'company name': 'Trimble Inc.',
#   'sektor': 'Electronic Equipment & Instruments'},
#  {'ticker': 'TFC', 'company name': 'Truist', 'sektor': 'Regional Banks'},
#  {'ticker': 'TYL',
#   'company name': 'Tyler Technologies',
#   'sektor': 'Application Software'},
#  {'ticker': 'TSN',
#   'company name': 'Tyson Foods',
#   'sektor': 'Packaged Foods & Meats'},
#  {'ticker': 'USB', 'company name': 'U.S. Bank', 'sektor': 'Diversified Banks'},
#  {'ticker': 'UBER',
#   'company name': 'Uber',
#   'sektor': 'Passenger Ground Transportation'},
#  {'ticker': 'UDR',
#   'company name': 'UDR, Inc.',
#   'sektor': 'Multi-Family Residential REITs'},
#  {'ticker': 'ULTA',
#   'company name': 'Ulta Beauty',
#   'sektor': 'Other Specialty Retail'},
#  {'ticker': 'UNP',
#   'company name': 'Union Pacific Corporation',
#   'sektor': 'Rail Transportation'},
#  {'ticker': 'UAL',
#   'company name': 'United Airlines Holdings',
#   'sektor': 'Passenger Airlines'},
#  {'ticker': 'UPS',
#   'company name': 'United Parcel Service',
#   'sektor': 'Air Freight & Logistics'},
#  {'ticker': 'URI',
#   'company name': 'United Rentals',
#   'sektor': 'Trading Companies & Distributors'},
#  {'ticker': 'UNH',
#   'company name': 'UnitedHealth Group',
#   'sektor': 'Managed Health Care'},
#  {'ticker': 'UHS',
#   'company name': 'Universal Health Services',
#   'sektor': 'Health Care Facilities'},
#  {'ticker': 'VLO',
#   'company name': 'Valero Energy',
#   'sektor': 'Oil & Gas Refining & Marketing'},
#  {'ticker': 'VTR', 'company name': 'Ventas', 'sektor': 'Health Care REITs'},
#  {'ticker': 'VLTO',
#   'company name': 'Veralto',
#   'sektor': 'Environmental & Facilities Services'},
#  {'ticker': 'VRSN',
#   'company name': 'Verisign',
#   'sektor': 'Internet Services & Infrastructure'},
#  {'ticker': 'VRSK',
#   'company name': 'Verisk',
#   'sektor': 'Research & Consulting Services'},
#  {'ticker': 'VZ',
#   'company name': 'Verizon',
#   'sektor': 'Integrated Telecommunication Services'},
#  {'ticker': 'VRTX',
#   'company name': 'Vertex Pharmaceuticals',
#   'sektor': 'Biotechnology'},
#  {'ticker': 'VTRS', 'company name': 'Viatris', 'sektor': 'Pharmaceuticals'},
#  {'ticker': 'VICI',
#   'company name': 'Vici Properties',
#   'sektor': 'Hotel & Resort REITs'},
#  {'ticker': 'V',
#   'company name': 'Visa Inc.',
#   'sektor': 'Transaction & Payment Processing Services'},
#  {'ticker': 'VST', 'company name': 'Vistra', 'sektor': 'Electric Utilities'},
#  {'ticker': 'VMC',
#   'company name': 'Vulcan Materials Company',
#   'sektor': 'Construction Materials'},
#  {'ticker': 'WRB',
#   'company name': 'W. R. Berkley Corporation',
#   'sektor': 'Property & Casualty Insurance'},
#  {'ticker': 'GWW',
#   'company name': 'W. W. Grainger',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'WAB',
#   'company name': 'Wabtec',
#   'sektor': 'Construction Machinery & Heavy Transportation Equipment'},
#  {'ticker': 'WBA',
#   'company name': 'Walgreens Boots Alliance',
#   'sektor': 'Drug Retail'},
#  {'ticker': 'WMT',
#   'company name': 'Walmart',
#   'sektor': 'Consumer Staples Merchandise Retail'},
#  {'ticker': 'DIS',
#   'company name': 'Walt Disney Company (The)',
#   'sektor': 'Movies & Entertainment'},
#  {'ticker': 'WBD',
#   'company name': 'Warner Bros. Discovery',
#   'sektor': 'Broadcasting'},
#  {'ticker': 'WM',
#   'company name': 'Waste Management',
#   'sektor': 'Environmental & Facilities Services'},
#  {'ticker': 'WAT',
#   'company name': 'Waters Corporation',
#   'sektor': 'Life Sciences Tools & Services'},
#  {'ticker': 'WEC',
#   'company name': 'WEC Energy Group',
#   'sektor': 'Electric Utilities'},
#  {'ticker': 'WFC',
#   'company name': 'Wells Fargo',
#   'sektor': 'Diversified Banks'},
#  {'ticker': 'WELL',
#   'company name': 'Welltower',
#   'sektor': 'Health Care REITs'},
#  {'ticker': 'WST',
#   'company name': 'West Pharmaceutical Services',
#   'sektor': 'Health Care Supplies'},
#  {'ticker': 'WDC',
#   'company name': 'Western Digital',
#   'sektor': 'Technology Hardware, Storage & Peripherals'},
#  {'ticker': 'WY', 'company name': 'Weyerhaeuser', 'sektor': 'Timber REITs'},
#  {'ticker': 'WMB',
#   'company name': 'Williams Companies',
#   'sektor': 'Oil & Gas Storage & Transportation'},
#  {'ticker': 'WTW',
#   'company name': 'Willis Towers Watson',
#   'sektor': 'Insurance Brokers'},
#  {'ticker': 'WYNN',
#   'company name': 'Wynn Resorts',
#   'sektor': 'Casinos & Gaming'},
#  {'ticker': 'XEL', 'company name': 'Xcel Energy', 'sektor': 'Multi-Utilities'},
#  {'ticker': 'XYL',
#   'company name': 'Xylem Inc.',
#   'sektor': 'Industrial Machinery & Supplies & Components'},
#  {'ticker': 'YUM', 'company name': 'Yum! Brands', 'sektor': 'Restaurants'},
#  {'ticker': 'ZBRA',
#   'company name': 'Zebra Technologies',
#   'sektor': 'Electronic Equipment & Instruments'},
#  {'ticker': 'ZBH',
#   'company name': 'Zimmer Biomet',
#   'sektor': 'Health Care Equipment'},
#  {'ticker': 'ZTS', 'company name': 'Zoetis', 'sektor': 'Pharmaceuticals'}]

# %%
# Get Timeseries data in Yahoo
def get_data_from_yahoo(reload_sp500 = False):
    if reload_sp500:
        tickers = save_sp500_tickers()
    else:
        with open("sp500tickers.pickle", "rb") as f:
            tickers = pickle.load(f)
    if not os.path.exists('stock_dfs2'):
        os.makedirs('stock_dfs2')
    
    start = dt.datetime(2000,1,1)
    end = dt.datetime(2020,5,28)

    # Grab all ticker data
    for s in tickers[401:500]:
        print(s)
        stock = s['ticker']
        if not os.path.exists('stock_dfs2/{}.csv'.format(stock)):
            try:
                kk = yf.Ticker(stock)
                end_date = datetime.now().strftime('%Y-%m-%d')
                df = kk.history(start='2020-01-01',end=end_date,interval='1d')
                df.to_csv('stock_dfs2/{}.csv'.format(stock))
            except:
                print(f"Problems retrieving data for {stock}. Skipping!")
            else:
                print('Already have {}'.format(stock))

get_data_from_yahoo()
# Out:
# {'ticker': 'RMD', 'company name': 'ResMed', 'sektor': 'Health Care Equipment'}
# Already have RMD
# {'ticker': 'RVTY', 'company name': 'Revvity', 'sektor': 'Health Care Equipment'}
# Already have RVTY
# {'ticker': 'ROK', 'company name': 'Rockwell Automation', 'sektor': 'Electrical Components & Equipment'}
# Already have ROK
# {'ticker': 'ROL', 'company name': 'Rollins, Inc.', 'sektor': 'Environmental & Facilities Services'}
# Already have ROL
# {'ticker': 'ROP', 'company name': 'Roper Technologies', 'sektor': 'Electronic Equipment & Instruments'}
# Already have ROP
# {'ticker': 'ROST', 'company name': 'Ross Stores', 'sektor': 'Apparel Retail'}
# Already have ROST
# {'ticker': 'RCL', 'company name': 'Royal Caribbean Group', 'sektor': 'Hotels, Resorts & Cruise Lines'}
# Already have RCL
# {'ticker': 'SPGI', 'company name': 'S&P Global', 'sektor': 'Financial Exchanges & Data'}
# Already have SPGI
# {'ticker': 'CRM', 'company name': 'Salesforce', 'sektor': 'Application Software'}
# Already have CRM
# {'ticker': 'SBAC', 'company name': 'SBA Communications', 'sektor': 'Telecom Tower REITs'}
# Already have SBAC
# {'ticker': 'SLB', 'company name': 'Schlumberger', 'sektor': 'Oil & Gas Equipment & Services'}
# Already have SLB
# {'ticker': 'STX', 'company name': 'Seagate Technology', 'sektor': 'Technology Hardware, Storage & Peripherals'}
# Already have STX
# {'ticker': 'SRE', 'company name': 'Sempra', 'sektor': 'Multi-Utilities'}
# Already have SRE
# {'ticker': 'NOW', 'company name': 'ServiceNow', 'sektor': 'Systems Software'}
# Already have NOW
# {'ticker': 'SHW', 'company name': 'Sherwin-Williams', 'sektor': 'Specialty Chemicals'}
# Already have SHW
# {'ticker': 'SPG', 'company name': 'Simon Property Group', 'sektor': 'Retail REITs'}
# Already have SPG
# {'ticker': 'SWKS', 'company name': 'Skyworks Solutions', 'sektor': 'Semiconductors'}
# Already have SWKS
# {'ticker': 'SJM', 'company name': 'J.M. Smucker Company (The)', 'sektor': 'Packaged Foods & Meats'}
# Already have SJM
# {'ticker': 'SW', 'company name': 'Smurfit WestRock', 'sektor': 'Paper & Plastic Packaging Products & Materials'}
# Already have SW
# {'ticker': 'SNA', 'company name': 'Snap-on', 'sektor': 'Industrial Machinery & Supplies & Components'}
# Already have SNA
# {'ticker': 'SOLV', 'company name': 'Solventum', 'sektor': 'Health Care Technology'}
# Already have SOLV
# {'ticker': 'SO', 'company name': 'Southern Company', 'sektor': 'Electric Utilities'}
# Already have SO
# {'ticker': 'LUV', 'company name': 'Southwest Airlines', 'sektor': 'Passenger Airlines'}
# Already have LUV
# {'ticker': 'SWK', 'company name': 'Stanley Black & Decker', 'sektor': 'Industrial Machinery & Supplies & Components'}
# Already have SWK
# {'ticker': 'SBUX', 'company name': 'Starbucks', 'sektor': 'Restaurants'}
# Already have SBUX
# {'ticker': 'STT', 'company name': 'State Street Corporation', 'sektor': 'Asset Management & Custody Banks'}
# Already have STT
# {'ticker': 'STLD', 'company name': 'Steel Dynamics', 'sektor': 'Steel'}
# Already have STLD
# {'ticker': 'STE', 'company name': 'Steris', 'sektor': 'Health Care Equipment'}
# Already have STE
# {'ticker': 'SYK', 'company name': 'Stryker Corporation', 'sektor': 'Health Care Equipment'}
# Already have SYK
# {'ticker': 'SMCI', 'company name': 'Supermicro', 'sektor': 'Technology Hardware, Storage & Peripherals'}
# Already have SMCI
# {'ticker': 'SYF', 'company name': 'Synchrony Financial', 'sektor': 'Consumer Finance'}
# Already have SYF
# {'ticker': 'SNPS', 'company name': 'Synopsys', 'sektor': 'Application Software'}
# Already have SNPS
# {'ticker': 'SYY', 'company name': 'Sysco', 'sektor': 'Food Distributors'}
# Already have SYY
# {'ticker': 'TMUS', 'company name': 'T-Mobile US', 'sektor': 'Wireless Telecommunication Services'}
# Already have TMUS
# {'ticker': 'TROW', 'company name': 'T. Rowe Price', 'sektor': 'Asset Management & Custody Banks'}
# Already have TROW
# {'ticker': 'TTWO', 'company name': 'Take-Two Interactive', 'sektor': 'Interactive Home Entertainment'}
# Already have TTWO
# {'ticker': 'TPR', 'company name': 'Tapestry, Inc.', 'sektor': 'Apparel, Accessories & Luxury Goods'}
# Already have TPR
# {'ticker': 'TRGP', 'company name': 'Targa Resources', 'sektor': 'Oil & Gas Storage & Transportation'}
# Already have TRGP
# {'ticker': 'TGT', 'company name': 'Target Corporation', 'sektor': 'Consumer Staples Merchandise Retail'}
# Already have TGT
# {'ticker': 'TEL', 'company name': 'TE Connectivity', 'sektor': 'Electronic Manufacturing Services'}
# Already have TEL
# {'ticker': 'TDY', 'company name': 'Teledyne Technologies', 'sektor': 'Electronic Equipment & Instruments'}
# Already have TDY
# {'ticker': 'TFX', 'company name': 'Teleflex', 'sektor': 'Health Care Equipment'}
# Already have TFX
# {'ticker': 'TER', 'company name': 'Teradyne', 'sektor': 'Semiconductor Materials & Equipment'}
# Already have TER
# {'ticker': 'TSLA', 'company name': 'Tesla, Inc.', 'sektor': 'Automobile Manufacturers'}
# Already have TSLA
# {'ticker': 'TXN', 'company name': 'Texas Instruments', 'sektor': 'Semiconductors'}
# Already have TXN
# {'ticker': 'TXT', 'company name': 'Textron', 'sektor': 'Aerospace & Defense'}
# Already have TXT
# {'ticker': 'TMO', 'company name': 'Thermo Fisher Scientific', 'sektor': 'Life Sciences Tools & Services'}
# Already have TMO
# {'ticker': 'TJX', 'company name': 'TJX Companies', 'sektor': 'Apparel Retail'}
# Already have TJX
# {'ticker': 'TSCO', 'company name': 'Tractor Supply', 'sektor': 'Other Specialty Retail'}
# Already have TSCO
# {'ticker': 'TT', 'company name': 'Trane Technologies', 'sektor': 'Building Products'}
# Already have TT
# {'ticker': 'TDG', 'company name': 'TransDigm Group', 'sektor': 'Aerospace & Defense'}
# Already have TDG
# {'ticker': 'TRV', 'company name': 'Travelers Companies (The)', 'sektor': 'Property & Casualty Insurance'}
# Already have TRV
# {'ticker': 'TRMB', 'company name': 'Trimble Inc.', 'sektor': 'Electronic Equipment & Instruments'}
# Already have TRMB
# {'ticker': 'TFC', 'company name': 'Truist', 'sektor': 'Regional Banks'}
# Already have TFC
# {'ticker': 'TYL', 'company name': 'Tyler Technologies', 'sektor': 'Application Software'}
# Already have TYL
# {'ticker': 'TSN', 'company name': 'Tyson Foods', 'sektor': 'Packaged Foods & Meats'}
# Already have TSN
# {'ticker': 'USB', 'company name': 'U.S. Bank', 'sektor': 'Diversified Banks'}
# Already have USB
# {'ticker': 'UBER', 'company name': 'Uber', 'sektor': 'Passenger Ground Transportation'}
# Already have UBER
# {'ticker': 'UDR', 'company name': 'UDR, Inc.', 'sektor': 'Multi-Family Residential REITs'}
# Already have UDR
# {'ticker': 'ULTA', 'company name': 'Ulta Beauty', 'sektor': 'Other Specialty Retail'}
# Already have ULTA
# {'ticker': 'UNP', 'company name': 'Union Pacific Corporation', 'sektor': 'Rail Transportation'}
# Already have UNP
# {'ticker': 'UAL', 'company name': 'United Airlines Holdings', 'sektor': 'Passenger Airlines'}
# Already have UAL
# {'ticker': 'UPS', 'company name': 'United Parcel Service', 'sektor': 'Air Freight & Logistics'}
# Already have UPS
# {'ticker': 'URI', 'company name': 'United Rentals', 'sektor': 'Trading Companies & Distributors'}
# Already have URI
# {'ticker': 'UNH', 'company name': 'UnitedHealth Group', 'sektor': 'Managed Health Care'}
# Already have UNH
# {'ticker': 'UHS', 'company name': 'Universal Health Services', 'sektor': 'Health Care Facilities'}
# Already have UHS
# {'ticker': 'VLO', 'company name': 'Valero Energy', 'sektor': 'Oil & Gas Refining & Marketing'}
# Already have VLO
# {'ticker': 'VTR', 'company name': 'Ventas', 'sektor': 'Health Care REITs'}
# Already have VTR
# {'ticker': 'VLTO', 'company name': 'Veralto', 'sektor': 'Environmental & Facilities Services'}
# Already have VLTO
# {'ticker': 'VRSN', 'company name': 'Verisign', 'sektor': 'Internet Services & Infrastructure'}
# Already have VRSN
# {'ticker': 'VRSK', 'company name': 'Verisk', 'sektor': 'Research & Consulting Services'}
# Already have VRSK
# {'ticker': 'VZ', 'company name': 'Verizon', 'sektor': 'Integrated Telecommunication Services'}
# Already have VZ
# {'ticker': 'VRTX', 'company name': 'Vertex Pharmaceuticals', 'sektor': 'Biotechnology'}
# Already have VRTX
# {'ticker': 'VTRS', 'company name': 'Viatris', 'sektor': 'Pharmaceuticals'}
# Already have VTRS
# {'ticker': 'VICI', 'company name': 'Vici Properties', 'sektor': 'Hotel & Resort REITs'}
# Already have VICI
# {'ticker': 'V', 'company name': 'Visa Inc.', 'sektor': 'Transaction & Payment Processing Services'}
# Already have V
# {'ticker': 'VST', 'company name': 'Vistra', 'sektor': 'Electric Utilities'}
# Already have VST
# {'ticker': 'VMC', 'company name': 'Vulcan Materials Company', 'sektor': 'Construction Materials'}
# Already have VMC
# {'ticker': 'WRB', 'company name': 'W. R. Berkley Corporation', 'sektor': 'Property & Casualty Insurance'}
# Already have WRB
# {'ticker': 'GWW', 'company name': 'W. W. Grainger', 'sektor': 'Industrial Machinery & Supplies & Components'}
# Already have GWW
# {'ticker': 'WAB', 'company name': 'Wabtec', 'sektor': 'Construction Machinery & Heavy Transportation Equipment'}
# Already have WAB
# {'ticker': 'WBA', 'company name': 'Walgreens Boots Alliance', 'sektor': 'Drug Retail'}
# Already have WBA
# {'ticker': 'WMT', 'company name': 'Walmart', 'sektor': 'Consumer Staples Merchandise Retail'}
# Already have WMT
# {'ticker': 'DIS', 'company name': 'Walt Disney Company (The)', 'sektor': 'Movies & Entertainment'}
# Already have DIS
# {'ticker': 'WBD', 'company name': 'Warner Bros. Discovery', 'sektor': 'Broadcasting'}
# Already have WBD
# {'ticker': 'WM', 'company name': 'Waste Management', 'sektor': 'Environmental & Facilities Services'}
# Already have WM
# {'ticker': 'WAT', 'company name': 'Waters Corporation', 'sektor': 'Life Sciences Tools & Services'}
# Already have WAT
# {'ticker': 'WEC', 'company name': 'WEC Energy Group', 'sektor': 'Electric Utilities'}
# Already have WEC
# {'ticker': 'WFC', 'company name': 'Wells Fargo', 'sektor': 'Diversified Banks'}
# Already have WFC
# {'ticker': 'WELL', 'company name': 'Welltower', 'sektor': 'Health Care REITs'}
# Already have WELL
# {'ticker': 'WST', 'company name': 'West Pharmaceutical Services', 'sektor': 'Health Care Supplies'}
# Already have WST
# {'ticker': 'WDC', 'company name': 'Western Digital', 'sektor': 'Technology Hardware, Storage & Peripherals'}
# Already have WDC
# {'ticker': 'WY', 'company name': 'Weyerhaeuser', 'sektor': 'Timber REITs'}
# Already have WY
# {'ticker': 'WMB', 'company name': 'Williams Companies', 'sektor': 'Oil & Gas Storage & Transportation'}
# Already have WMB
# {'ticker': 'WTW', 'company name': 'Willis Towers Watson', 'sektor': 'Insurance Brokers'}
# Already have WTW
# {'ticker': 'WYNN', 'company name': 'Wynn Resorts', 'sektor': 'Casinos & Gaming'}
# Already have WYNN
# {'ticker': 'XEL', 'company name': 'Xcel Energy', 'sektor': 'Multi-Utilities'}
# Already have XEL
# {'ticker': 'XYL', 'company name': 'Xylem Inc.', 'sektor': 'Industrial Machinery & Supplies & Components'}
# Already have XYL
# {'ticker': 'YUM', 'company name': 'Yum! Brands', 'sektor': 'Restaurants'}
# Already have YUM

# %%
def scrape_data_yahoo(stock_code,endpoint):
    headers = {
        # ISI HEADER
    }

    url = 'https://finance.yahoo.com/quote/' + stock_code + '/' + endpoint + '/'
    response = requests.get(url, headers=headers)
    tree = html.fromstring(response.content)
    divs = tree.xpath("//div[contains(@class, 'column') and contains(@class, 'yf-1ezv2n5')]")
    header = []
    for div in divs:
        text = div.text_content().strip() 
        header.append(text)
    feature=['Date']
    body = tree.xpath("//div[contains(@class, 'column') and contains(@class, 'sticky') and contains(@class, 'yf-1xjz32c')]")
    for isi in body:
        text = isi.text_content().strip() 
        feature.append(text)
    isi_data =[]
    data = tree.xpath("//div[contains(@class, 'column') and not(contains(@class, 'sticky')) and contains(@class, 'yf-1xjz32c')]")
    for isi in data:
        text = isi.text_content().strip() 
        isi_data.append(text)
    # print(isi_data)
    list_kelompok=[[header[i] for i in range(1,len(header))]]
    jumlah_per_kelompok = len(header)-1
    for i in range(0, len(isi_data), jumlah_per_kelompok):
        kelompok = isi_data[i:i + jumlah_per_kelompok]
        list_kelompok.append(kelompok)
    df = pd.DataFrame(columns=feature)
    n = np.array(list_kelompok).T.tolist()
    df = pd.DataFrame(n,columns=feature)
    return df

def scrape_lapkeu(stock_code):
    if not os.path.exists('Laporan_keuangan'):
        os.makedirs('Laporan_keuangan')
    df = scrape_data_yahoo(stock,'financials')
    df2 = scrape_data_yahoo(stock,'balance-sheet')
    df3 = scrape_data_yahoo(stock,'cash-flow')
    df_gabungan  = pd.merge(df, df2, on='Date', how='outer')
    df_gabungan  = pd.merge(df_gabungan, df3, on='Date', how='outer')
    df_gabungan
    df_gabungan.to_csv('Laporan_keuangan/'+stock_code+'_laporan_keuangan.csv', index=False)

# scrape_lapkeu('AMZN')

# %%
def get_lapkeu(reload_sp500 = False):
    if reload_sp500:
        tickers = save_sp500_tickers()
    else:
        with open("sp500tickers.pickle", "rb") as f:
            tickers = pickle.load(f)
    for s in tickers[201:500]:
        stock = s['ticker']
        scrape_lapkeu(stock)

# %%
get_lapkeu()
